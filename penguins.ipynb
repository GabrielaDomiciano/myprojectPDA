# %% [markdown]
# # Palmer Penguins
#
#
# *********************************
#
#
# ![Penguins](img/lter_penguins.png)

# %% [markdown]
# ### This notebook contains my analysis of the Palmer Penguins Dataset.
# ##### Author: Gabriela Domiciano Avellar
# ##### Project:  Principles of Data Analytics
#
#
# You can find the data set on GitHub [on GitHub](https://allisonhorst.github.io/palmerpenguins/).
# Data were collected and made available by [Kristen Gorman](https://www.uaf.edu/cfos/people/faculty/detail/kristen-gorman.php) and the [Palmer Station, Antarctica LTER](https://pallter.marine.rutgers.edu), a member of the [Long Term Ecological Research Network](https://lternet.edu)
#
#
#
# This dataset contains information about 3 different species of penguins and was collected from 3 different islands, the Palmer archipelago in Antarctica. The data contains characteristics of the penguins, bill length, bill depth, flipper legth, bodymass and sex and  island name and  species name.
# .... continue

# %% [markdown]
# # Imports
# ***
#
# - Pandas: for the DataFrame, it allows to investigate CSV files, amongst other features.
# - Matplotlib.pyplot: for creating plots
# - Numpy: for working with arrays.
# - Seaborn: matplotlib sub-library for creating attractive data visualisation.

# %%
# Data frames.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Load Data
# ***
#
# Load the Palmer penguins data set from a URL

# %%
# Load the penguins data set.
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv")

# %% [markdown]
#  The data is now loaded and we can inspect it.
#
#  The Data has 344 rows and 7 columns, it is separate by species, island, bill lenghth, bill depth, flipper legth, body mass and sex.

# %%
# Let's have a look.
display(df)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]

# %%
# deletar coluna vazia
df = df.dropna()
display(df)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 4         3450.0  FEMALE
# 5         3650.0    MALE
# 6         3625.0  FEMALE
# ..           ...     ...
# 338       4925.0  FEMALE
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [332 rows x 7 columns]

# %%
# Describe the data set.
# Statistics for all numeric columns in the DataFrame.

display(df.describe())
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      332.000000     332.000000         332.000000   332.000000
# mean        44.007530      17.160241         201.027108  4208.433735
# std          5.470296       1.970397          13.993822   806.038643
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.700000      17.300000         197.000000  4050.000000
# 75%         48.625000      18.700000         213.000000  4781.250000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
# Look at the fisrt row
df.iloc[0]
# Out:
# species                 Adelie
# island               Torgersen
# bill_length_mm            39.5
# bill_depth_mm             17.4
# flipper_length_mm        186.0
# body_mass_g             3800.0
# sex                     FEMALE
# Name: 1, dtype: object

# %%
# Showing the first 10 rows and quantity of rows and columns.

display(df.head(10))
print(df.shape)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 13  Adelie  Torgersen            38.6           21.2              191.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
# 15  Adelie  Torgersen            36.6           17.8              185.0
#
#     body_mass_g     sex
# 1        3800.0  FEMALE
# 2        3250.0  FEMALE
# 4        3450.0  FEMALE
# 5        3650.0    MALE
# 6        3625.0  FEMALE
# 7        4675.0    MALE
# 12       3200.0  FEMALE
# 13       3800.0    MALE
# 14       4400.0    MALE
# 15       3700.0  FEMALE
# (332, 7)

# %%
display(df.loc[10:20])
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 13  Adelie  Torgersen            38.6           21.2              191.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
# 15  Adelie  Torgersen            36.6           17.8              185.0
# 16  Adelie  Torgersen            38.7           19.0              195.0
# 17  Adelie  Torgersen            42.5           20.7              197.0
# 18  Adelie  Torgersen            34.4           18.4              184.0
# 19  Adelie  Torgersen            46.0           21.5              194.0
# 20  Adelie     Biscoe            37.8           18.3              174.0
#
#     body_mass_g     sex
# 12       3200.0  FEMALE
# 13       3800.0    MALE
# 14       4400.0    MALE
# 15       3700.0  FEMALE
# 16       3450.0  FEMALE
# 17       4500.0    MALE
# 18       3325.0  FEMALE
# 19       4200.0    MALE
# 20       3400.0  FEMALE

# %%
# Pegar linhas que correspodem a uma condicao
island_df = df.loc[df['island'] == 'Biscoe']
display(island_df)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20   Adelie  Biscoe            37.8           18.3              174.0
# 21   Adelie  Biscoe            37.7           18.7              180.0
# 22   Adelie  Biscoe            35.9           19.2              189.0
# 23   Adelie  Biscoe            38.2           18.1              185.0
# 24   Adelie  Biscoe            38.8           17.2              180.0
# ..      ...     ...             ...            ...                ...
# 338  Gentoo  Biscoe            47.2           13.7              214.0
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 20        3400.0  FEMALE
# 21        3600.0    MALE
# 22        3800.0  FEMALE
# 23        3950.0    MALE
# 24        3800.0    MALE
# ..           ...     ...
# 338       4925.0  FEMALE
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [163 rows x 7 columns]

# %%
# The bill legth and bill depth  per specie.

specie_length = df[['species', 'bill_length_mm']]
display(specie_length)

specie_length = df[['species', 'bill_depth_mm']]
display(specie_length)
# Out:
#     species  bill_length_mm
# 1    Adelie            39.5
# 2    Adelie            40.3
# 4    Adelie            36.7
# 5    Adelie            39.3
# 6    Adelie            38.9
# ..      ...             ...
# 338  Gentoo            47.2
# 340  Gentoo            46.8
# 341  Gentoo            50.4
# 342  Gentoo            45.2
# 343  Gentoo            49.9
#
# [332 rows x 2 columns]
#     species  bill_depth_mm
# 1    Adelie           17.4
# 2    Adelie           18.0
# 4    Adelie           19.3
# 5    Adelie           20.6
# 6    Adelie           17.8
# ..      ...            ...
# 338  Gentoo           13.7
# 340  Gentoo           14.3
# 341  Gentoo           15.7
# 342  Gentoo           14.8
# 343  Gentoo           16.1
#
# [332 rows x 2 columns]

# %%
# Get the bill legtgh.
len = df['bill_length_mm']

# Show.
print(len)

# Type.
print(type(len))
# Out:
# 1      39.5
# 2      40.3
# 4      36.7
# 5      39.3
# 6      38.9
#        ...
# 338    47.2
# 340    46.8
# 341    50.4
# 342    45.2
# 343    49.9
# Name: bill_length_mm, Length: 332, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
# Get the numpy array.
len = len.to_numpy()

# Show.
len
# Out:
# array([39.5, 40.3, 36.7, 39.3, 38.9, 39.2, 41.1, 38.6, 34.6, 36.6, 38.7,
#        42.5, 34.4, 46. , 37.8, 37.7, 35.9, 38.2, 38.8, 35.3, 40.6, 40.5,
#        37.9, 40.5, 39.5, 37.2, 39.5, 40.9, 36.4, 39.2, 38.8, 42.2, 37.6,
#        39.8, 36.5, 40.8, 36. , 44.1, 37. , 39.6, 41.1, 36. , 42.3, 39.6,
#        40.1, 35. , 42. , 34.5, 41.4, 39. , 40.6, 36.5, 37.6, 35.7, 41.3,
#        37.6, 41.1, 36.4, 41.6, 35.5, 41.1, 35.9, 41.8, 33.5, 39.7, 39.6,
#        45.8, 35.5, 42.8, 40.9, 37.2, 36.2, 42.1, 34.6, 42.9, 36.7, 35.1,
#        37.3, 41.3, 36.3, 36.9, 38.3, 38.9, 35.7, 41.1, 34. , 39.6, 36.2,
#        40.8, 38.1, 40.3, 33.1, 43.2, 35. , 41. , 37.7, 37.8, 37.9, 39.7,
#        38.6, 38.2, 38.1, 43.2, 38.1, 45.6, 39.7, 42.2, 39.6, 42.7, 38.6,
#        37.3, 35.7, 41.1, 36.2, 37.7, 40.2, 41.4, 35.2, 40.6, 38.8, 41.5,
#        39. , 44.1, 38.5, 43.1, 36.8, 37.5, 38.1, 41.1, 35.6, 40.2, 37. ,
#        39.7, 40.2, 40.6, 32.1, 40.7, 37.3, 39. , 39.2, 36.6, 36. , 37.8,
#        36. , 41.5, 46.5, 50. , 51.3, 45.4, 52.7, 45.2, 46.1, 51.3, 46. ,
#        51.3, 46.6, 51.7, 47. , 52. , 45.9, 50.5, 50.3, 58. , 46.4, 49.2,
#        42.4, 48.5, 43.2, 50.6, 46.7, 52. , 50.5, 49.5, 46.4, 52.8, 40.9,
#        54.2, 42.5, 51. , 49.7, 47.5, 47.6, 52. , 46.9, 53.5, 49. , 46.2,
#        50.9, 45.5, 50.9, 50.8, 50.1, 49. , 51.5, 49.8, 48.1, 51.4, 45.7,
#        50.7, 42.5, 52.2, 45.2, 49.3, 50.2, 45.6, 51.9, 46.8, 45.7, 55.8,
#        43.5, 49.6, 50.8, 50.2, 46.1, 50. , 48.7, 50. , 47.6, 46.5, 45.4,
#        46.7, 43.3, 46.8, 40.9, 49. , 45.5, 48.4, 45.8, 49.3, 42. , 49.2,
#        46.2, 48.7, 50.2, 45.1, 46.5, 46.3, 42.9, 46.1, 47.8, 48.2, 50. ,
#        47.3, 42.8, 45.1, 59.6, 49.1, 48.4, 42.6, 44.4, 44. , 48.7, 42.7,
#        49.6, 45.3, 49.6, 50.5, 43.6, 45.5, 50.5, 44.9, 45.2, 46.6, 48.5,
#        45.1, 50.1, 46.5, 45. , 43.8, 45.5, 43.2, 50.4, 45.3, 46.2, 45.7,
#        54.3, 45.8, 49.8, 49.5, 43.5, 50.7, 47.7, 46.4, 48.2, 46.5, 46.4,
#        48.6, 47.5, 51.1, 45.2, 45.2, 49.1, 52.5, 47.4, 50. , 44.9, 50.8,
#        43.4, 51.3, 47.5, 52.1, 47.5, 52.2, 45.5, 49.5, 44.5, 50.8, 49.4,
#        46.9, 48.4, 51.1, 48.5, 55.9, 47.2, 49.1, 46.8, 41.7, 53.4, 43.3,
#        48.1, 50.5, 49.8, 43.5, 51.5, 46.2, 55.1, 48.8, 47.2, 46.8, 50.4,
#        45.2, 49.9])

# %%
# Bill Depth.
dep = df['bill_depth_mm'].to_numpy()

# Show.
dep
# Out:
# array([17.4, 18. , 19.3, 20.6, 17.8, 19.6, 17.6, 21.2, 21.1, 17.8, 19. ,
#        20.7, 18.4, 21.5, 18.3, 18.7, 19.2, 18.1, 17.2, 18.9, 18.6, 17.9,
#        18.6, 18.9, 16.7, 18.1, 17.8, 18.9, 17. , 21.1, 20. , 18.5, 19.3,
#        19.1, 18. , 18.4, 18.5, 19.7, 16.9, 18.8, 19. , 17.9, 21.2, 17.7,
#        18.9, 17.9, 19.5, 18.1, 18.6, 17.5, 18.8, 16.6, 19.1, 16.9, 21.1,
#        17. , 18.2, 17.1, 18. , 16.2, 19.1, 16.6, 19.4, 19. , 18.4, 17.2,
#        18.9, 17.5, 18.5, 16.8, 19.4, 16.1, 19.1, 17.2, 17.6, 18.8, 19.4,
#        17.8, 20.3, 19.5, 18.6, 19.2, 18.8, 18. , 18.1, 17.1, 18.1, 17.3,
#        18.9, 18.6, 18.5, 16.1, 18.5, 17.9, 20. , 16. , 20. , 18.6, 18.9,
#        17.2, 20. , 17. , 19. , 16.5, 20.3, 17.7, 19.5, 20.7, 18.3, 17. ,
#        20.5, 17. , 18.6, 17.2, 19.8, 17. , 18.5, 15.9, 19. , 17.6, 18.3,
#        17.1, 18. , 17.9, 19.2, 18.5, 18.5, 17.6, 17.5, 17.5, 20.1, 16.5,
#        17.9, 17.1, 17.2, 15.5, 17. , 16.8, 18.7, 18.6, 18.4, 17.8, 18.1,
#        17.1, 18.5, 17.9, 19.5, 19.2, 18.7, 19.8, 17.8, 18.2, 18.2, 18.9,
#        19.9, 17.8, 20.3, 17.3, 18.1, 17.1, 19.6, 20. , 17.8, 18.6, 18.2,
#        17.3, 17.5, 16.6, 19.4, 17.9, 19. , 18.4, 19. , 17.8, 20. , 16.6,
#        20.8, 16.7, 18.8, 18.6, 16.8, 18.3, 20.7, 16.6, 19.9, 19.5, 17.5,
#        19.1, 17. , 17.9, 18.5, 17.9, 19.6, 18.7, 17.3, 16.4, 19. , 17.3,
#        19.7, 17.3, 18.8, 16.6, 19.9, 18.8, 19.4, 19.5, 16.5, 17. , 19.8,
#        18.1, 18.2, 19. , 18.7, 13.2, 16.3, 14.1, 15.2, 14.5, 13.5, 14.6,
#        15.3, 13.4, 15.4, 13.7, 16.1, 13.7, 14.6, 14.6, 15.7, 13.5, 15.2,
#        14.5, 15.1, 14.3, 14.5, 14.5, 15.8, 13.1, 15.1, 15. , 14.3, 15.3,
#        15.3, 14.2, 14.5, 17. , 14.8, 16.3, 13.7, 17.3, 13.6, 15.7, 13.7,
#        16. , 13.7, 15. , 15.9, 13.9, 13.9, 15.9, 13.3, 15.8, 14.2, 14.1,
#        14.4, 15. , 14.4, 15.4, 13.9, 15. , 14.5, 15.3, 13.8, 14.9, 13.9,
#        15.7, 14.2, 16.8, 16.2, 14.2, 15. , 15. , 15.6, 15.6, 14.8, 15. ,
#        16. , 14.2, 16.3, 13.8, 16.4, 14.5, 15.6, 14.6, 15.9, 13.8, 17.3,
#        14.4, 14.2, 14. , 17. , 15. , 17.1, 14.5, 16.1, 14.7, 15.7, 15.8,
#        14.6, 14.4, 16.5, 15. , 17. , 15.5, 15. , 16.1, 14.7, 15.8, 14. ,
#        15.1, 15.2, 15.9, 15.2, 16.3, 14.1, 16. , 16.2, 13.7, 14.3, 15.7,
#        14.8, 16.1])

# %%
# Simple plot.
plt.plot(len, dep, 'o')

# Axis labels.
plt.xlabel('Bill Length (mm)')
plt.ylabel('Bill Depth (mm)')

# Title.
plt.title('Palmer Penguins')

# X limits.
#plt.xlim(0, 8)

# Y limits.
#plt.ylim(0, 4)
# Out:
# Text(0.5, 1.0, 'Palmer Penguins')

# %%
# Simple plot.
plt.plot(len, spe, 'o')

# Axis labels.
plt.xlabel('Bill Length (mm)')
plt.ylabel('Specie')

# Title.
plt.title('Palmer Penguins')

# X limits.
#plt.xlim(0, 8)

# Y limits.
#plt.ylim(0, 4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[835], line 2
#       1 # Simple plot.
# ----> 2 plt.plot(len, spe, 'o')
#       4 # Axis labels.
#       5 plt.xlabel('Bill Length (mm)')
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (332,) and (344,)

# %%
# Simple plot.
plt.plot(dep, spe,  'o')

# Axis labels.
plt.xlabel('Bill Depth (mm)')
plt.ylabel('Specie')

# Title.
plt.title('Palmer Penguins')
# Out:
# Text(0.5, 1.0, 'Palmer Penguins')

# %%
# Number de penguins per specie 
df['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
# Number of penguins per Island
data = df['island'].value_counts()
print(data)

island = ['Biscoe', 'Dream', 'Torgesen'] 
fig = plt.figure(figsize =(10, 7)) 
plt.pie(data, labels=island) 
plt.title('Número de pinguins por ilha')
plt.legend(title='Quantidade por ilha', labels=data)

plt.show()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
# sex of penguis.
df['sex']
# Out:
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3         NaN
# 4      FEMALE
#         ...
# 339       NaN
# 340    FEMALE
# 341      MALE
# 342    FEMALE
# 343      MALE
# Name: sex, Length: 344, dtype: object

# %%
# count the number of penguins of each sex
df['sex'].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64

# %%
# count the number of male and female per island
df[['island', 'sex']].value_counts()
# Out:
# island     sex
# Biscoe     MALE      83
#            FEMALE    80
# Dream      MALE      62
#            FEMALE    61
# Torgersen  FEMALE    24
#            MALE      23
# Name: count, dtype: int64

# %%
# the type of species per island
df[['island', 'species']].value_counts()
# Out:
# island     species
# Biscoe     Gentoo       124
# Dream      Chinstrap     68
#            Adelie        56
# Torgersen  Adelie        52
# Biscoe     Adelie        44
# Name: count, dtype: int64

# %% [markdown]
# ***

# %%
# Get just bill legtgh.
#len = df['bill_length_mm']

# Show.
#print(len)

# Type.
#print(type(len))

# %%
# Just get the numpy array.
#len = len.to_numpy()

# Show.
#len

# %%
# Bill Depth.
#dep = df['bill_depth_mm'].to_numpy()

# Show.
#dep

# %%
# Simple plot.
#plt.plot(len, dep, 'o')

# Axis labels.
#plt.xlabel('Bill Length (mm)')
#plt.ylabel('Bill Depth (mm)')

# Title.
#plt.title('Palmer Penguins')

# X limits.
#plt.xlim(0, 8)

# Y limits.
#plt.ylim(0, 4)

# %%
# Species.
spe = df['species'].to_numpy()

# Show.
spe
# Out:
# array(['Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap', 'Chinstrap',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo'], dtype=object)

# %%
# Simple plot.
#plt.plot(len, spe, 'o')

# Axis labels.
#plt.xlabel('Bill Length (mm)')
#plt.ylabel('Specie')

# Title.
#plt.title('Palmer Penguins')

# X limits.
#plt.xlim(0, 8)

# Y limits.
#plt.ylim(0, 4)

# %%
# Simple plot.
#plt.plot(dep, spe,  'o')

# Axis labels.
#plt.xlabel('Bill Depth (mm)')
#plt.ylabel('Specie')

# Title.
#plt.title('Palmer Penguins')

# %% [markdown]
# ***

# %% [markdown]
# # This will be big
#
# This will be a paragraph. This *will* be a paragraph. This will be a paragraph. This will be a paragraph. This will be a paragraph. This will be a paragraph.This will be a paragraph. This will be a paragraph. This **will** be a paragraph.This will be a paragraph. This will be a paragraph. This will be a paragraph. This will be a paragraph. This will be a paragraph. This will be a paragraph. This will be a paragraph. This will be a paragraph. This will be a paragraph. This will be a paragraph.This will be a paragraph.This will be a paragraph.This will be a paragraph.This will be a paragraph.This will be a paragraph.This will be a paragraph.
#
# # This will be smaller
# ##### this will be smaller.
#
# - bullet
# - point
# - lists
# ##### Bigger again
#
# 1. Numbered bullets
# 2. Just use numbers

# %% [markdown]
# ## Tables
#
# ***
#
#
# |Species     |Bill Lenght (mm) |Body Mass (g)|
# |------------|----------------:|------------:|
# |Adelie      |             38.8|         3101|
# |Chinstrap   |             48.8|         3733|
# |Gentoo      |             47.5|         5076|

# %% [markdown]
# ***
# print ("Python is a great language!")
#
# a = a + 1
#
# print(a)
# ***

# %% [markdown]
# ## Math
#
# ***
#
# $f(x) = x^2$
#
# ***

# %%
library(tidyverse)
penguins
  count(species)
penguins
  group_by(species
  summarize(across(where(is.numeric), mean, na.rm = TRUE))
# Out:
#   Cell In[811], line 3
#     count(species)
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ***
# ## End
