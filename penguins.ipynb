# %% [markdown]
# # Palmer Penguins
#
#
# *********************************
#
#
# ![Penguins](img/lter_penguins.png)

# %% [markdown]
# ### This notebook contains my analysis of the Palmer Penguins Dataset.
# ##### Author: Gabriela Domiciano Avellar
# ##### Project:  Principles of Data Analytics
#
#
# You can find the data set [on GitHub](https://allisonhorst.github.io/palmerpenguins/).
# Data were collected and made available by [Kristen Gorman](https://www.uaf.edu/cfos/people/faculty/detail/kristen-gorman.php) and the [Palmer Station, Antarctica LTER](https://pallter.marine.rutgers.edu), a member of the [Long Term Ecological Research Network](https://lternet.edu)
#
#
#
# This dataset contains information about 3 different species of penguins and was collected from 3 different islands in the Palmer Archipelago in Antarctica. The data contains characteristics of the penguins, bill length, bill depth, flipper length, body mass, sex, island name, and species name.
# To develop the project and analyze the database, I used the following as a reference:
#
# - Classes we had over the semester, the code used as reference [Professor Ian McLoughlin Git Hub](https://github.com/ianmcloughlin/mywork/blob/main/iris.ipynb)
# - Python Plotting With Matplotlib [Real Python](https://realpython.com/python-matplotlib-guide/#understanding-pltsubplots-notation)
# - [Matplotlib](https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html)
# - [GitHub Docs](https://docs.github.com/en/repositories/managing-your-repositorys-settings-and-features/customizing-your-repository/about-readmes)
# - I used the ChatGpt to help understand some codes, asking to explain in simple ways.
# - Information about de [Palmer Penguins](https://allisonhorst.github.io/palmerpenguins/articles/intro.html).
# - Following YouTube videos I watched in Portuguese, if you want to watch them, you can enable the subtitles:
#   - [Hastag Programacao](https://www.youtube.com/watch?v=kCMaqla6Grs)
#   - [Hastag Programacao](https://www.youtube.com/watch?v=FDU-D8ddTU4)

# %% [markdown]
# # Imports
# ***
#
# - Pandas: for the DataFrame, it allows to investigation of CSV files, amongst other features.
# - Matplotlib.pyplot: for creating plots
# - Numpy: for working with arrays.
# - Seaborn: matplotlib sub-library for creating attractive data visualization.

# %%
# Data frames.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Load Data
# ***
#
# Load the Palmer penguins data set from a URL

# %%
# Load the penguins data set.
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv")

# %% [markdown]
#  The data is now loaded and we can inspect it.
#
#  The Data has 344 rows and 7 columns, it is separated by species, island, bill length, bill depth, flipper length, body mass, and sex.

# %%
# Let's have a look.
display(df)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
# Empty columns were deleted.
df = df.dropna()
display(df)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
# Describe the data set.
# Statistics for all numeric columns in the DataFrame.

display(df.describe())
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
# Look at the first row.
df.iloc[0]
# Out:
# species                 Adelie
# island               Torgersen
# bill_length_mm            39.1
# bill_depth_mm             18.7
# flipper_length_mm        181.0
# body_mass_g             3750.0
# sex                       MALE
# Name: 0, dtype: object

# %%
# Showing the first 10 rows and quantity of rows and columns.

display(df.head(10))
print(df.shape)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 13  Adelie  Torgersen            38.6           21.2              191.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
#
#     body_mass_g     sex
# 0        3750.0    MALE
# 1        3800.0  FEMALE
# 2        3250.0  FEMALE
# 4        3450.0  FEMALE
# 5        3650.0    MALE
# ...

# %%
# We can see between the 10 and 20 rows 
display(df.loc[10:20])
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 13  Adelie  Torgersen            38.6           21.2              191.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
# 15  Adelie  Torgersen            36.6           17.8              185.0
# 16  Adelie  Torgersen            38.7           19.0              195.0
# 17  Adelie  Torgersen            42.5           20.7              197.0
# 18  Adelie  Torgersen            34.4           18.4              184.0
# 19  Adelie  Torgersen            46.0           21.5              194.0
# 20  Adelie     Biscoe            37.8           18.3              174.0
#
#     body_mass_g     sex
# 12       3200.0  FEMALE
# 13       3800.0    MALE
# 14       4400.0    MALE
# 15       3700.0  FEMALE
# 16       3450.0  FEMALE
# 17       4500.0    MALE
# 18       3325.0  FEMALE
# 19       4200.0    MALE
# ...

# %%
# Get lines that match a condition.
# It shows all the species that are on the Island of Biscoe.
island_df = df.loc[df['island'] == 'Biscoe']
display(island_df)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20   Adelie  Biscoe            37.8           18.3              174.0
# 21   Adelie  Biscoe            37.7           18.7              180.0
# 22   Adelie  Biscoe            35.9           19.2              189.0
# 23   Adelie  Biscoe            38.2           18.1              185.0
# 24   Adelie  Biscoe            38.8           17.2              180.0
# ..      ...     ...             ...            ...                ...
# 338  Gentoo  Biscoe            47.2           13.7              214.0
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 20        3400.0  FEMALE
# 21        3600.0    MALE
# 22        3800.0  FEMALE
# ...

# %%
# Number the penguins per species.
df['species'].value_counts()
# Out:
# species
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: count, dtype: int64

# %%
# More information about the specie Gento.
gento_df = df.loc[df['species'] == 'Gentoo', ['species', 'sex', 'body_mass_g']]
display(gento_df)
# Out:
#     species     sex  body_mass_g
# 220  Gentoo  FEMALE       4500.0
# 221  Gentoo    MALE       5700.0
# 222  Gentoo  FEMALE       4450.0
# 223  Gentoo    MALE       5700.0
# 224  Gentoo    MALE       5400.0
# ..      ...     ...          ...
# 338  Gentoo  FEMALE       4925.0
# 340  Gentoo  FEMALE       4850.0
# 341  Gentoo    MALE       5750.0
# 342  Gentoo  FEMALE       5200.0
# 343  Gentoo    MALE       5400.0
#
# [119 rows x 3 columns]

# %%
 # Additional details regarding the Gento species.
specie_df = df.loc[df['species'] == 'Gentoo', ['species', 'bill_length_mm', 'bill_depth_mm']]
display(specie_df)
# Out:
#     species  bill_length_mm  bill_depth_mm
# 220  Gentoo            46.1           13.2
# 221  Gentoo            50.0           16.3
# 222  Gentoo            48.7           14.1
# 223  Gentoo            50.0           15.2
# 224  Gentoo            47.6           14.5
# ..      ...             ...            ...
# 338  Gentoo            47.2           13.7
# 340  Gentoo            46.8           14.3
# 341  Gentoo            50.4           15.7
# 342  Gentoo            45.2           14.8
# 343  Gentoo            49.9           16.1
#
# [119 rows x 3 columns]

# %%
# We can see here specific information for a row and column.
print(df.loc[29, 'island'])
# Out:
# Biscoe

# %%
# The bill length per species.

specie_length = df[['species', 'bill_length_mm']]
# Show.
print(specie_length)

# Type.
print(type(specie_length))
# Out:
#     species  bill_length_mm
# 0    Adelie            39.1
# 1    Adelie            39.5
# 2    Adelie            40.3
# 4    Adelie            36.7
# 5    Adelie            39.3
# ..      ...             ...
# 338  Gentoo            47.2
# 340  Gentoo            46.8
# 341  Gentoo            50.4
# 342  Gentoo            45.2
# 343  Gentoo            49.9
#
# [333 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
# The bill depth per species.
specie_depth = df[['species', 'bill_depth_mm']]
print(specie_depth)

# Type.
print(type(specie_depth))
# Out:
#     species  bill_depth_mm
# 0    Adelie           18.7
# 1    Adelie           17.4
# 2    Adelie           18.0
# 4    Adelie           19.3
# 5    Adelie           20.6
# ..      ...            ...
# 338  Gentoo           13.7
# 340  Gentoo           14.3
# 341  Gentoo           15.7
# 342  Gentoo           14.8
# 343  Gentoo           16.1
#
# [333 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
# Bill depth to numpy.
dep = df['bill_depth_mm'].to_numpy()

# Show.
dep
# Out:
# array([18.7, 17.4, 18. , 19.3, 20.6, 17.8, 19.6, 17.6, 21.2, 21.1, 17.8,
#        19. , 20.7, 18.4, 21.5, 18.3, 18.7, 19.2, 18.1, 17.2, 18.9, 18.6,
#        17.9, 18.6, 18.9, 16.7, 18.1, 17.8, 18.9, 17. , 21.1, 20. , 18.5,
#        19.3, 19.1, 18. , 18.4, 18.5, 19.7, 16.9, 18.8, 19. , 17.9, 21.2,
#        17.7, 18.9, 17.9, 19.5, 18.1, 18.6, 17.5, 18.8, 16.6, 19.1, 16.9,
#        21.1, 17. , 18.2, 17.1, 18. , 16.2, 19.1, 16.6, 19.4, 19. , 18.4,
#        17.2, 18.9, 17.5, 18.5, 16.8, 19.4, 16.1, 19.1, 17.2, 17.6, 18.8,
#        19.4, 17.8, 20.3, 19.5, 18.6, 19.2, 18.8, 18. , 18.1, 17.1, 18.1,
#        17.3, 18.9, 18.6, 18.5, 16.1, 18.5, 17.9, 20. , 16. , 20. , 18.6,
#        18.9, 17.2, 20. , 17. , 19. , 16.5, 20.3, 17.7, 19.5, 20.7, 18.3,
#        17. , 20.5, 17. , 18.6, 17.2, 19.8, 17. , 18.5, 15.9, 19. , 17.6,
#        18.3, 17.1, 18. , 17.9, 19.2, 18.5, 18.5, 17.6, 17.5, 17.5, 20.1,
#        16.5, 17.9, 17.1, 17.2, 15.5, 17. , 16.8, 18.7, 18.6, 18.4, 17.8,
# ...

# %%
# Bill lenght to numpy.
leng = df['bill_length_mm'].to_numpy()

# Show.
leng
# Out:
# array([39.1, 39.5, 40.3, 36.7, 39.3, 38.9, 39.2, 41.1, 38.6, 34.6, 36.6,
#        38.7, 42.5, 34.4, 46. , 37.8, 37.7, 35.9, 38.2, 38.8, 35.3, 40.6,
#        40.5, 37.9, 40.5, 39.5, 37.2, 39.5, 40.9, 36.4, 39.2, 38.8, 42.2,
#        37.6, 39.8, 36.5, 40.8, 36. , 44.1, 37. , 39.6, 41.1, 36. , 42.3,
#        39.6, 40.1, 35. , 42. , 34.5, 41.4, 39. , 40.6, 36.5, 37.6, 35.7,
#        41.3, 37.6, 41.1, 36.4, 41.6, 35.5, 41.1, 35.9, 41.8, 33.5, 39.7,
#        39.6, 45.8, 35.5, 42.8, 40.9, 37.2, 36.2, 42.1, 34.6, 42.9, 36.7,
#        35.1, 37.3, 41.3, 36.3, 36.9, 38.3, 38.9, 35.7, 41.1, 34. , 39.6,
#        36.2, 40.8, 38.1, 40.3, 33.1, 43.2, 35. , 41. , 37.7, 37.8, 37.9,
#        39.7, 38.6, 38.2, 38.1, 43.2, 38.1, 45.6, 39.7, 42.2, 39.6, 42.7,
#        38.6, 37.3, 35.7, 41.1, 36.2, 37.7, 40.2, 41.4, 35.2, 40.6, 38.8,
#        41.5, 39. , 44.1, 38.5, 43.1, 36.8, 37.5, 38.1, 41.1, 35.6, 40.2,
#        37. , 39.7, 40.2, 40.6, 32.1, 40.7, 37.3, 39. , 39.2, 36.6, 36. ,
# ...

# %%
# Simple linear regression to find the relation between the depth and length of the Pengins' bill.

depth_np = specie_df['bill_depth_mm'].to_numpy()
len_np = specie_df['bill_length_mm'].to_numpy()

m, c = np.polyfit(depth_np, len_np, 1)
m, c
# Out:
# (2.0603207554909635, 16.670181342443897)

# %%
# Creates a scatterplot showing data points for  depth versus length.
plt.scatter(depth_np, len_np)
plt.ylabel('bill_depth')
plt.xlabel('bill_length')
plt.title('Penguins Bill Depth and Length')
labely = plt.plot(depth_np, m * depth_np + c, 'r-')

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Deeper bill in penguins may indicate a greater likelihood of longer length. 🐧📏

# %%
# Number of penguins per Island
data = df['island'].value_counts()
print(data)

island = ['Biscoe', 'Dream', 'Torgesen'] 
fig = plt.figure(figsize =(10, 7)) 
plt.pie(data, labels=island) 
plt.title('Number of penguins per Island')
plt.legend(title='Quantity per island', labels=data)

plt.show()
# Out:
# island
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: count, dtype: int64

# %%
# Sex of penguins.
df['sex']
# Out:
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 4      FEMALE
# 5        MALE
#         ...
# 338    FEMALE
# 340    FEMALE
# 341      MALE
# 342    FEMALE
# 343      MALE
# Name: sex, Length: 333, dtype: object

# %%
# Count the number of penguins of each sex.
df['sex'].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64

# %%
# Count the number of males and females per island.
df[['island', 'sex']].value_counts()
# Out:
# island     sex
# Biscoe     MALE      83
#            FEMALE    80
# Dream      MALE      62
#            FEMALE    61
# Torgersen  FEMALE    24
#            MALE      23
# Name: count, dtype: int64

# %% [markdown]
# ***
# ## End
